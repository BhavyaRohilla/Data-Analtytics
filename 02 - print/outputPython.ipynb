# %% [markdown]
# # Output in Python
# - print()

# %% [markdown]
# # Values
#
# - Numerical value without decimal Ex: 14, 15, -24
# - Numerical value with decimal Ex: 1.5, 19.2,-39.8
# - Non Numerical value Ex: "Bhavya","da"

# %% [markdown]
# #### print a single value

# %%
print(12)
# Out:
# 12

# %%
print(20.5)
# Out:
# 20.5

# %%
print("Bhavya")
# Out:
# Bhavya

# %% [markdown]
# ### print multiple values

# %%
print(12,14,15, sep=",")
# Out:
# 12,14,15

# %%
print("Bhavya", "Rama", sep=":::")            #seprator : in between values
# Out:
# Bhavya:::Rama

# %%
print(12,13)
# Out:
# 12 13

# %% [markdown]
# ### print a single variable

# %%
a = 10
print(a)
# Out:
# 10

# %%
a = 10
a
# Out:
# 10

# %% [markdown]
# - in jupyter notbook, the last line of the cell will be either print or assigned

# %% [markdown]
# ### print multiple variable

# %%
a = 10
b = 20
print(a,b)
# Out:
# 10 20

# %%
a,b,c = 10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %% [markdown]
# #### print (combination of both value and variable)

# %%
print(12,a)
# Out:
# 12 10

# %%
print("The value of a : ",a)
# Out:
# The value of a :  10

# %%
print("The value of a : ",a, "The value of b : ",b)
# Out:
# The value of a :  10 The value of b :  20

# %%
print(a,"Bhavya")
# Out:
# 10 Bhavya

# %%
print(a)
# Out:
# 10

# %%
print("a")
# Out:
# a
