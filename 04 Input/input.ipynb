# %% [markdown]
# ### Input
#
# - want to take the input from the user. in Python, we have the input() function.
# - By default it take as "str" datatype

# %%
x = 10

# %%
x = input()

# %%
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# str
